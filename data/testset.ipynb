# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /opt/anaconda3/lib/python3.12/site-packages (1.17.0)
# Requirement already satisfied: click>=8.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (0.27.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.14.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (0.1.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from huggingface_hub import login

login()

# %%
from huggingface_hub import hf_hub_download

test_path = hf_hub_download(
    repo_id="netop/TeleLogs",
    filename="troubleshooting/test.json",
    repo_type="dataset"
)

print(test_path)
# Out:
# /Users/hayoungcheon/.cache/huggingface/hub/datasets--netop--TeleLogs/snapshots/05c6eb6ead151ff90ee3746c2bbc87a83ce3c471/troubleshooting/test.json

# %%
import json

with open(test_path, "r") as f:
    test = json.load(f)

len(test)
# Out:
# 864

# %%
from huggingface_hub import hf_hub_download
import shutil

path = hf_hub_download(
    repo_id="netop/TeleLogs",
    filename="troubleshooting/test.json",
    repo_type="dataset"
)

# Copy to your project folder
shutil.copy(path, "./test.json")

print("Downloaded!")
# Out:
# Downloaded!
